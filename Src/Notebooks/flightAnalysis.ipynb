# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("../../Data/Raw/handthrowndata_2.csv")

# %%
df.head()
# Out:
#    Index   RawAltitude   KalmanAltitude    ax    ay    az   Acceleration  \
# 0      0       1566.97          1554.67  1.70  4.99  0.59           9.33
# 1      1       1567.93          1560.07  3.19  5.18  0.66           8.96
# 2      2       1567.93          1562.51  4.65  5.97  0.02           9.88
# 3      3       1568.12          1564.03  6.03  6.31 -0.45           9.25
# 4      4       1567.74          1565.04  7.20  5.32  0.96           8.75
#
#     isApogee1   isApogee2   isApogee3
# 0           0           0           0
# 1           0           0           0
# 2           0           0           0
# 3           0           0           0
# 4           0           0           0

# %%
df.columns
# Out:
# Index(['Index', ' RawAltitude', ' KalmanAltitude', ' ax', ' ay', ' az',
#        ' Acceleration', ' isApogee1', ' isApogee2', ' isApogee3'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 10))
plt.plot(df.Index, df[' ax'],  linewidth=2, color="r", label="RawAltitude")
plt.plot(df.Index, df[' ay'],  linewidth=2, color="y", label="KalmanAltitude")
plt.plot(df.Index, df[' az'],  linewidth=2, color="b", label="Acceleration")
plt.legend()
plt.show()
